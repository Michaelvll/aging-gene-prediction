# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import math 
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
cell_types = os.listdir('../../../ml_input/')
for c in cell_types: 
    print(c)
# Out:
# L23_IT_CTX_Glut
# DG_Glut
# CA1-ProS_Glut
# Astro-TE_NN
# Oligo_NN
# L6_IT_CTX_Glut
# L5_ET_CTX_Glut
# CA3_Glut
# Pvalb_Gaba
# L6_CT_CTX_Glut
# OPC_NN

# %%
FEATURE_FILENAME_DICT = {'p_enhancer_DMR' : 'abc_enhancer.DMR_gene.csv',
                         'hic_enhancer_peak' : 'abc_enhancer.peak_gene.csv', 
                         # 'DAR' : 'aDAR_gene.csv', 
                         'mCG_DMR' : 'aDMR_gene.csv',
                         'hic_loops' : 'Loop_gene.csv.gz', 
                         'mCG_genebody' : 'mCG_genebody_gene.csv', 
                         'mCH_genebody' : 'mCH_genebody_gene.csv', 
                         'atac_peaks' : 'peak_gene.csv', 
                         'luisa_rna' : 'luisa_RNA_DEG.csv', 
                         'inhouse_rna' : 'RNA_DEG.csv'}

# %%
### Need to run all of the cells underneath this (with the functions) for this loop to work. 
for ct in cell_types: 
    filepath = f"/gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ml_input/{ct}/"
    
    outpath = Path(f"/gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/{ct}/")
    outpath.mkdir(exist_ok=True, parents=True)
    
    l_rna_file = 'luisa_rna'
    i_rna_file = 'inhouse_rna'

    df_rna, df_rna_i = rna(ct, filepath)
    df_meta = meta(ct, df_rna)
    df_atac = atac(ct)
    df_mch_gb = mch_gb(ct)
    df_mcg_gb = mcg_gb(ct)
    df_hic = hic(ct)
    df_dmr = dmr(ct)
    # df_dar = dar(ct)
    df_abc_peak = abc_peak(ct)
    df_abc_dmr = abc_dmr(ct)
# Out:
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L23_IT_CTX_Glut/L23_IT_CTX_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/DG_Glut/DG_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA1-ProS_Glut/CA1-ProS_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Astro-TE_NN/Astro-TE_NN.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Oligo_NN/Oligo_NN.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_IT_CTX_Glut/L6_IT_CTX_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L5_ET_CTX_Glut/L5_ET_CTX_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/CA3_Glut/CA3_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/Pvalb_Gaba/Pvalb_Gaba.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/L6_CT_CTX_Glut/L6_CT_CTX_Glut.enhancer_DMR.csv
# Output for Luisa RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.luisa_rna.csv
# Output for RNA
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.inhouse_rna.csv
# Output for Meta
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.meta.csv
# Output for atac
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.atac.csv
# Output for mch_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.mch_genebody.csv
# Output for mcg_genebody
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.mcg_genebody.csv
# Output for loops
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.loops.csv
# Output for DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.DMR.csv
# Output for DAR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.DAR.csv
# Output for enhancer_peak
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.enhancer_peak.csv
# Output for enhancer_DMR
# /gale/ddn/aging/aklein/240903_aging_mice/aging_gene_prediction/aging_gene_prediction/ak_workspace/data/v3/OPC_NN/OPC_NN.enhancer_DMR.csv

# %% [markdown]
# # Functions

# %% [markdown]
# ## RNA

# %%
def rna(ct, filepath):
    df_rna = pd.read_csv(f'{filepath}/{ct}.{FEATURE_FILENAME_DICT[l_rna_file]}', index_col=0)
    print(f"Output for Luisa RNA")
    print(f"{outpath}/{ct}.luisa_rna.csv")
    
    df_rna.to_csv(f"{outpath}/{ct}.luisa_rna.csv")
    
    df_rna_i = pd.read_csv(f'{filepath}/{ct}.{FEATURE_FILENAME_DICT[i_rna_file]}', index_col=0)
    print(f"Output for RNA")
    print(f"{outpath}/{ct}.inhouse_rna.csv")
    
    df_rna_i.to_csv(f"{outpath}/{ct}.inhouse_rna.csv")

    return df_rna, df_rna_i

# %% [markdown]
# ## Meta

# %%
def meta(ct, df_rna): 
    # blank dataframe for meta
    df_meta = pd.DataFrame(index = df_rna.index)
    
    # Get the gene length from the genebody files
    rel_path = FEATURE_FILENAME_DICT['mcg_genebody']
    fullpath = f'{filepath}/{ct}.{rel_path}'
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    df_meta['gene_length'] = df_feat.groupby('gene_name', observed=False)['gene_length'].mean()
    
    # get the gene type and chromosome number form the DAR / DMR files
    rel_path = FEATURE_FILENAME_DICT['DAR']
    fullpath = f'{filepath}/{ct}.{rel_path}'
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    df_meta['gene_type'] = df_feat.groupby('gene_name', observed=False)['gene_type'].first()
    df_meta['gene_chr'] = df_feat.groupby('gene_name', observed=False)['gene_chr'].first()
    
    df_meta.index.name = 'gene_name'

    print(f"Output for Meta")
    print(f"{outpath}/{ct}.meta.csv")
    
    df_meta.to_csv(f"{outpath}/{ct}.meta.csv")
    return df_meta

# %% [markdown]
# ## ATAC

# %%
# Read the atac file (if it exists)
def gen_atac_features(_feat, fullpath): 
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    # df_feat.head()

    # The list of features to generate
    ATAC_FEATURES = ['9mo.2mo.log_ratio', '18mo.9mo.log_ratio' , '18mo.2mo.log_ratio', 'log2_distance']
    df_feat['9mo.2mo.log_ratio'] = np.log2(df_feat['9mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    df_feat['18mo.9mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['9mo'] + 1e-10)
    df_feat['18mo.2mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    df_feat['log2_distance'] = np.log2((df_feat['distance']).abs().astype(np.float64) + 1e-10)

    # the aggregating functions (Just mean and std for ATAC Features) 
    df_mean = df_feat.groupby("gene_name", observed=True)[ATAC_FEATURES].mean()
    df_mean.columns = [f"{c}.mean" for c in df_mean.columns]
    
    df_std = df_feat.groupby("gene_name", observed=True)[ATAC_FEATURES].std()
    df_std.columns = [f"{c}.std" for c in df_std.columns]

    df_max = df_feat.groupby("gene_name", observed=True)[ATAC_FEATURES].max()
    df_max.columns = [f"{c}.max" for c in df_max.columns]

    df_min = df_feat.groupby("gene_name", observed=True)[ATAC_FEATURES].min()
    df_min.columns = [f"{c}.min" for c in df_min.columns]
    
    df_res = df_mean.merge(df_std, left_on='gene_name', right_on = 'gene_name')
    df_res = df_res.merge(df_max, left_on='gene_name', right_on = 'gene_name')
    df_res = df_res.merge(df_min, left_on='gene_name', right_on = 'gene_name')
    df_res['count'] = df_feat.groupby("gene_name", observed=True).size()

    return df_res
    # print("Missing Values:")
    # print(pd.isna(df_res).sum() / df_res.shape[0] * 100)

# %%
def atac(ct):
    _feat = 'atac'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_atac = gen_atac_features(_feat, fullpath)
            
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        
        df_atac.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_atac

# %% [markdown]
# ## Genebody

# %%
def gen_genebody_features(_feat, fullpath): 
    # Read the dataframe
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    # display(df_feat.head())

    # The list of features to generate
    GENEBODY_FEATURES = ['9mo.2mo.log_ratio', '18mo.9mo.log_ratio', '18mo.2mo.log_ratio']
    df_feat['9mo.2mo.log_ratio'] = np.log2(df_feat['9mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    df_feat['18mo.9mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['9mo'] + 1e-10)
    df_feat['18mo.2mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)

    df_res = df_feat.groupby("gene_name", observed=True)[GENEBODY_FEATURES].mean()
    return df_res

# %%
def mch_gb(ct):
    _feat = 'mch_genebody'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_gb_mch = gen_genebody_features(_feat, fullpath)
        
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_gb_mch.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_gb_mch

# %%
def mcg_gb(ct):
    _feat = 'mcg_genebody'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_gb_mcg = gen_genebody_features(_feat, fullpath)
        
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_gb_mcg.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_gb_mcg

# %% [markdown]
# ## Loops
#
# The question: Should I be binning loops by the loop size? That is generating the mean, std, skew, max, min for different loop sizes?

# %%
def gen_loop_features(_feat, fullpath):
    # Read in data file
    df_feat = pd.read_csv(fullpath).set_index('gene_name')

    # The features to generate
    LOOP_FEATURES = ['Qanova', 'Tanova', '9mo.2mo.Q', '18mo.9mo.Q', '18mo.2mo.Q', '9mo.2mo.T', '18mo.9mo.T', '18mo.2mo.T', 'loop_size.log', 'min_distance.log']
    df_feat['9mo.2mo.Q'] = df_feat['9mo.Q'] - df_feat['2mo.Q']
    df_feat['18mo.9mo.Q'] = df_feat['18mo.Q'] - df_feat['9mo.Q']
    df_feat['18mo.2mo.Q'] = df_feat['18mo.Q'] - df_feat['2mo.Q']
    df_feat['9mo.2mo.T'] = df_feat['9mo.T'] - df_feat['2mo.T']
    df_feat['18mo.9mo.T'] = df_feat['18mo.T'] - df_feat['9mo.T']
    df_feat['18mo.2mo.T'] = df_feat['18mo.T'] - df_feat['2mo.T']
    df_feat['loop_size.log'] = np.log2((df_feat['anchor2_distance'] - df_feat['anchor1_distance']).abs().astype(np.float64) + 10000) #10000 is the loop resolution
    df_feat['min_distance.log'] = np.log2(df_feat[['anchor1_distance', 'anchor2_distance']].min(axis=1).abs().astype(np.float64) + 10000) #10000 is the loop resolution
    
    # The aggregating functions to use: 
    funct_names = ['mean', 'median', 'std', 'max', 'min']
    df_res = df_feat.groupby("gene_name", observed=True)[LOOP_FEATURES].agg(funct_names)
    df_res.columns = df_res.columns.map('.'.join).str.strip('.')
    df_res['count'] = df_feat.groupby("gene_name", observed=True).size()
    
    return df_res

# %%
def hic(ct): 
    _feat = 'loops'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_loop = gen_loop_features(_feat, fullpath)
        
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_loop.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_loop

# %% [markdown]
# ## Differential Regions

# %%
def gen_DMR_features(_feat, fullpath):
    # Read data file
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    
    DMR_FEATURES = ['size.log2', 'rel_pos', '9mo.2mo.log_ratio', '18mo.9mo.log_ratio', '18mo.2mo.log_ratio', 'distance.log2']
    
    df_feat['size.log2'] = np.log2(df_feat['end'] - df_feat['start'] + 1e-10)
    df_feat['rel_pos'] = (df_feat['start'] - df_feat['gene_start']) / (df_feat['gene_end'] - df_feat['gene_start'])
    df_feat['distance.log2'] = np.log2(df_feat['distance'] + 1e-10)
    df_feat['9mo.2mo.log_ratio'] = np.log2(df_feat['9mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    df_feat['18mo.9mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['9mo'] + 1e-10)
    df_feat['18mo.2mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    
    df_res = df_feat.groupby("gene_name", observed=True)[DMR_FEATURES].mean()
    df_res['count'] = df_feat.groupby("gene_name", observed=True).size()
    
    return df_res

# %%
def gen_DAR_features(_feat, fullpath):
    # Read data file
    df_feat = pd.read_csv(fullpath).set_index('gene_name')
    
    DAR_FEATURES = ['rel_pos', '9mo.2mo.log_ratio', '18mo.9mo.log_ratio', '18mo.2mo.log_ratio']

    df_feat['rel_pos'] = (df_feat['start'] - df_feat['gene_start']) / (df_feat['gene_end'] - df_feat['gene_start'])
    df_feat['9mo.2mo.log_ratio'] = np.log2(df_feat['9mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    df_feat['18mo.9mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['9mo'] + 1e-10)
    df_feat['18mo.2mo.log_ratio'] = np.log2(df_feat['18mo'] + 1e-10) - np.log2(df_feat['2mo'] + 1e-10)
    
    df_res = df_feat.groupby("gene_name", observed=True)[DAR_FEATURES].mean()
    df_res['count'] = df_feat.groupby("gene_name", observed=True).size()
    
    return df_res

# %%
def dmr(ct):
    _feat = 'DMR'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_dmr = gen_DMR_features(_feat, fullpath)
    
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_dmr.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_dmr

# %%
def dar(ct):
    _feat = 'DAR'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_dar = gen_DAR_features(_feat, fullpath)
    
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_dar.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_dar

# %% [markdown]
# ## ABC Enhancers

# %%
def gen_abc_features(_feat, fullpath):
    # Read data file
    df_feat = pd.read_csv(fullpath) # .set_index('gene_name')

    # Features to generate
    ENHANCER_ABC_FEATURES = ['9mo.2mo.activity.log_ratio', '18mo.2mo.activity.log_ratio', '18mo.9mo.activity.log_ratio',
                             '9mo.2mo.contact.log_ratio', '18mo.2mo.contact.log_ratio', '18mo.9mo.contact.log_ratio',]
                             # '9mo.2mo.abc_score.log_ratio', '18mo.2mo.abc_score.log_ratio', '18mo.9mo.abc_score.log_ratio']

    df_feat['9mo.2mo.activity.log_ratio'] = np.log2(df_feat['9mo.activity'] + 1e-10) - np.log2(df_feat['2mo.activity'] + 1e-10)
    df_feat['18mo.2mo.activity.log_ratio'] = np.log2(df_feat['18mo.activity'] + 1e-10) - np.log2(df_feat['2mo.activity'] + 1e-10)
    df_feat['18mo.9mo.activity.log_ratio'] = np.log2(df_feat['18mo.activity'] + 1e-10) - np.log2(df_feat['9mo.activity'] + 1e-10)
    
    df_feat['9mo.2mo.contact.log_ratio'] = np.log2(df_feat['9mo.contact'] + 1e-10) - np.log2(df_feat['2mo.contact'] + 1e-10)
    df_feat['18mo.2mo.contact.log_ratio'] = np.log2(df_feat['18mo.contact'] + 1e-10) - np.log2(df_feat['2mo.contact'] + 1e-10)
    df_feat['18mo.9mo.contact.log_ratio'] = np.log2(df_feat['18mo.contact'] + 1e-10) - np.log2(df_feat['9mo.contact'] + 1e-10)
    
    # df_feat['9mo.2mo.abc_score.log_ratio'] = np.log2(df_feat['9mo.abc_score'] + 1e-10) - np.log2(df_feat['2mo.abc_score'] + 1e-10)
    # df_feat['18mo.2mo.abc_score.log_ratio'] = np.log2(df_feat['18mo.abc_score'] + 1e-10) - np.log2(df_feat['2mo.abc_score'] + 1e-10)
    # df_feat['18mo.9mo.abc_score.log_ratio'] = np.log2(df_feat['18mo.abc_score'] + 1e-10) - np.log2(df_feat['9mo.abc_score'] + 1e-10)

    df_feat['end_distance'] = abs(df_feat['start'] - df_feat['gene_end'])
    df_feat['start_distance'] = abs(df_feat['start'] - df_feat['gene_start'])
    df_feat['e_distance'] = df_feat[['end_distance', 'start_distance']].min(axis=1)
    df_feat = df_feat.drop(columns = ['end_distance', 'start_distance'])
    
    # binning by distance from gene: 
    eg_distance_cutoffs = [0, 5e3, 20e3, 5e6]
    bin_name_map = {'(0.0, 5000.0]' : '0 - 5kb', 
                    '(5000.0, 20000.0]' : '5kb - 20kb', 
                    '(20000.0, 5000000.0]' : '20kb - 5Mb',
                   }
    df_feat['binned_distance'] = pd.cut(df_feat['e_distance'], eg_distance_cutoffs)
    df_feat['binned_distance'] = df_feat['binned_distance'].apply(lambda x: bin_name_map[str(x)])
    df_feat['binned_distance'] = df_feat['binned_distance'].cat.reorder_categories([ '0 - 5kb', '5kb - 20kb', '20kb - 5Mb'], ordered=True)

    funct_names = ['mean', 'median', 'std', 'max', 'min', 'count']
    df_res = df_feat.groupby(['gene_name', 'binned_distance'], observed=True)[ENHANCER_ABC_FEATURES].agg(funct_names)
    df_res.columns = df_res.columns.map('.'.join).str.strip('.')

    df_res_dist = pd.DataFrame(index=df_feat['gene_name'].unique())
    df_res_dist.index.name = 'gene_name'

    df_res = df_res.reset_index().copy()
    for _cat in df_res['binned_distance'].cat.categories:
        cat = _cat.replace(" ", "")
        df_temp = df_res.loc[df_res['binned_distance'] == _cat]
        df_temp = df_temp.set_index('gene_name').drop(columns = "binned_distance")
        df_temp.columns = [f"{c}.{cat}" for c in df_temp.columns]
        df_res_dist = df_res_dist.merge(df_temp, how='left',  left_on='gene_name', right_on = 'gene_name')
        
    df_res_dist['count'] = df_feat.groupby("gene_name", observed=True).size()
    return df_res_dist

# %%
def abc_peak(ct): 
    _feat = 'enhancer_peak'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_abc_peak = gen_abc_features(_feat, fullpath)
        
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_abc_peak .to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_abc_peak

# %%
def abc_dmr(ct): 
    _feat = 'enhancer_DMR'
    rel_path = FEATURE_FILENAME_DICT[_feat]
    fullpath = f'{filepath}/{ct}.{rel_path}'
    if Path(fullpath).exists(): 
        df_abc_dmr = gen_abc_features(_feat, fullpath)
            
        print(f"Output for {_feat}")
        print(f"{outpath}/{ct}.{_feat}.csv")
        df_abc_dmr.to_csv(f"{outpath}/{ct}.{_feat}.csv")
        return df_abc_dmr

# %% [markdown]
# ## Old

# %%
    
    # # Mean 
    # df_feat_mean = pd.DataFrame(df_feat.groupby(['gene_name', 'binned_distance'], observed=True)[ENHANCER_ABC_FEATURES].mean()).reset_index()
    
    # df_feat_mean_dist = pd.DataFrame(index=df_feat['gene_name'].unique())
    # df_feat_mean_dist.index.name = 'gene_name'
    
    # for _cat in df_feat_mean['binned_distance'].cat.categories:
    #     # print(_cat, _cat.replace(" ", ""))
    #     cat = _cat.replace(" ", "")
        
    #     df_temp = df_feat_mean.loc[df_feat_mean['binned_distance'] == _cat]
    #     df_temp = df_temp.set_index('gene_name').drop(columns = "binned_distance")
    #     df_temp.columns = [f"{c}.{cat}" for c in df_temp.columns]
    #     df_feat_mean_dist = df_feat_mean_dist.merge(df_temp, left_on='gene_name', right_on = 'gene_name')
    
    # # Max 
    # df_feat_max = pd.DataFrame(df_feat.groupby(['gene_name', 'binned_distance'], observed=True)[ENHANCER_ABC_FEATURES].max()).reset_index()
    
    # df_feat_max_dist = pd.DataFrame(index=df_feat['gene_name'].unique())
    # df_feat_max_dist.index.name = 'gene_name'
    
    # for _cat in df_feat_max['binned_distance'].cat.categories:
    #     # print(_cat, _cat.replace(" ", ""))
    #     cat = _cat.replace(" ", "")
        
    #     df_temp = df_feat_max.loc[df_feat_max['binned_distance'] == _cat]
    #     df_temp = df_temp.set_index('gene_name').drop(columns = "binned_distance")
    #     df_temp.columns = [f"{c}.{cat}" for c in df_temp.columns]
    #     df_feat_max_dist = df_feat_max_dist.merge(df_temp, left_on='gene_name', right_on = 'gene_name')
    
    
    # # Min
    # df_feat_min = pd.DataFrame(df_feat.groupby(['gene_name', 'binned_distance'], observed=True)[ENHANCER_ABC_FEATURES].min()).reset_index()
    
    # df_feat_min_dist = pd.DataFrame(index=df_feat['gene_name'].unique())
    # df_feat_min_dist.index.name = 'gene_name'
    
    # for _cat in df_feat_min['binned_distance'].cat.categories:
    #     # print(_cat, _cat.replace(" ", ""))
    #     cat = _cat.replace(" ", "")
        
    #     df_temp = df_feat_min.loc[df_feat_min['binned_distance'] == _cat]
    #     df_temp = df_temp.set_index('gene_name').drop(columns = "binned_distance")
    #     df_temp.columns = [f"{c}.{cat}" for c in df_temp.columns]
    #     df_feat_min_dist = df_feat_min_dist.merge(df_temp, left_on='gene_name', right_on = 'gene_name')
    
    
    # # Merge
    # df_feat_res = df_feat_mean_dist.merge(df_feat_max_dist, left_on='gene_name', right_on = 'gene_name', suffixes=(".mean", ""))
    # df_feat_res = df_feat_res.merge(df_feat_min_dist, left_on='gene_name', right_on = 'gene_name', suffixes=(".max", ".min"))
    # # return df_feat_res
