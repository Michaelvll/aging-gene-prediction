# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

import PyComplexHeatmap as pch
from PyComplexHeatmap import *

plt.rcParams['figure.dpi']=100
plt.rcParams['savefig.dpi']=300
plt.rcParams['pdf.fonttype']=42

# %%
from sklearn.metrics import confusion_matrix
import scipy.cluster.hierarchy as spc

# %%
# all options are for different training regiments, I have found that _cs looks / performed best.
# "_b_cs", "_b", "_cs", ""
extension = "_cs"

# %%
# My ordering
cell_types = ['L23_IT_CTX_Glut','L5_ET_CTX_Glut','L6_IT_CTX_Glut','L6_CT_CTX_Glut','CA3_Glut','CA1-ProS_Glut','DG_Glut','Astro-TE_NN','Oligo_NN','OPC_NN',]
# To match RZ's ordering in her plots
cell_types = ['Oligo_NN', 'OPC_NN', 'Astro-TE_NN', 'L23_IT_CTX_Glut', 'L6_IT_CTX_Glut', 'L6_CT_CTX_Glut', 'L5_ET_CTX_Glut', 'CA1-ProS_Glut', 'CA3_Glut', 'DG_Glut']

# %% [markdown]
# ## Custom Colormap

# %%
from matplotlib.colors import LinearSegmentedColormap

# cmap = plt.get_cmap("coolwarm")
# cmap(np.linspace(0, 1, 5))

adj_coolwarm = LinearSegmentedColormap.from_list("adjusted_coolwarm", (
    (0.000, (0.2298057 , 0.29871797, 0.75368315)),
    (0.166, (0.55431187, 0.69009701, 0.99551555)),
    (0.333, (0.86742764, 0.8643766 , 0.86260246)),
    (0.666, (0.95665321, 0.59803382, 0.47730229)),
    (1.000, (0.70567316, 0.01555616, 0.15023281))))

import matplotlib
matplotlib.colormaps.register(adj_coolwarm)

adj_coolwarm

# %%
# import matplotlib
# matplotlib.colormaps.register(adj_coolwarm)

# %% [markdown]
# # From RZ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi']=300
plt.rcParams['pdf.fonttype']=42

# %%
#matplotlib.colormaps.register(adj_coolwarm)

fig, axes = plt.subplots(ncols = 5, nrows =2, figsize=(15, 6), dpi = 150, constrained_layout=True)

for path, ax in zip(all_fps, axes.ravel()):
    ct = path.split('/')[-2]
    ml_out = pd.read_csv(path)
    n_genes = ml_out.shape[0]
    confusion_matrix = pd.crosstab(ml_out['pred'], ml_out['DEG'], rownames=['Predicted'], colnames=['Actual'])
    confusion_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
    
    sns.heatmap(confusion_matrix, 
            ax =ax,
            cmap = adj_coolwarm,
            vmin = 0.2, vmax = 0.8,
            annot=True)
    ax.set_title(f'{ct}:{n_genes}') 

#fig.savefig('heatmap.accuracy.0-1.pdf', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 8), constrained_layout=True)
 
for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    Y_output = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.Y_outs.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf = confusion_matrix(Y_output['DEG'], Y_output['pred'], normalize='true')
    sns.heatmap(ccf, 
            ax =ax,
            cmap = adj_coolwarm,
            vmin = 0.2, vmax = 0.8,
            annot=True)
    # ax.set_title(f'{_ct}:{n_genes}') 
    
    Y_deg = Y_output[(Y_output['DEG'] == 0) | (Y_output['DEG'] == 2)]
    acc = sum(Y_deg.DEG == Y_deg.pred) / Y_deg.shape[0]
    
    ax.set_title(f"{_ct}; n = {n_sample}; acc = {acc*100 :.1f}%", fontsize=10)
    
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")

# fig.colorbar(g, ax=axes, ticks=[0.2, 0.4, 0.6, 0.8], label="", location='right', aspect=10, shrink=0.25, fraction=1)
fig.savefig("../images/fig6/ff_xgb_model_accuracies_2.pdf", bbox_inches= 'tight')
# plt.show()    
# plt.close()

# %% [markdown]
# # Fig. 6B
# Plotting the Accuracies for Oligo NN, L2/3, and CA1_ProS

# %%
acc_list = []
fig, axes = plt.subplots(2, 5, figsize=(20, 8), constrained_layout=True)
 
for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    # Y_output = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.cv{extension}.Y_outs.csv", index_col=0)
    Y_output = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.Y_outs.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf = confusion_matrix(Y_output['DEG'], Y_output['pred'], normalize='true')
    g = ax.imshow(ccf, cmap=adj_coolwarm, vmin=0.2, vmax=.8)
    ax.set(xticks=range(ccf.shape[1]), yticks=range(ccf.shape[0]), 
           xticklabels = ['-1', '0', '1'], yticklabels = ['-1', '0', '1'], 
           )
    sns.despine(left=True, bottom=True)

    for a in range(3):
        for b in range(3):
            ax.text(a, b, "%.2f"%(ccf[a, b]), size=12, va='center', ha='center', 
                   color = 'black' if (ccf[a,b] > 0.3) and (ccf[a,b] < 0.61) else 'white')

    Y_deg = Y_output[(Y_output['DEG'] == 0) | (Y_output['DEG'] == 2)]
    acc = sum(Y_deg.DEG == Y_deg.pred) / Y_deg.shape[0]
    # Y_temp = Y_output.loc[Y_output['DEG'] != 0]
    # acc_b = sum(Y_temp.DEG == Y_temp.pred) / Y_temp.shape[0]
    acc_list.append(acc)
    ax.set_title(f"{_ct}; n = {n_sample}; acc = {acc*100 :.1f}%", fontsize=10)
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")

for i in range(len(cell_types), 3): 
    axes.flatten()[i].remove()

fig.colorbar(g, ax=axes, ticks=[0.2, 0.4, 0.6, 0.8], label="", location='right', aspect=10, shrink=0.25, fraction=1)
fig.savefig("../images/fig6/ff_model_accuracies.pdf", bbox_inches= 'tight')
plt.show()    
plt.close()

# %% [markdown]
# #### Plotting the SHAP values x genes for the select cell types

# %%
palette = {-1: '#4287f5', 0: '#ebedf0', 1: '#f50511'}
FEATURE_LIST = ['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak'] #, 'meta']
FEATURE_MAP = {'DMR' : "Genebody DMR",
               'mcg_genebody' : "mCG Genebody",
               'mch_genebody' : "mCH Genebody",
               'atac' : "Genebody Peak",
               'DAR' : "Genebody Peak",
               'loops' : "HiC Loop",
               'enhancer_DMR' : "Enhancer DMR",
               'enhancer_peak' : "Enhancer Peak"
}
FEAT_ORDER = ["Genebody DMR", "mCG Genebody", "mCH Genebody", "Genebody Peak", "HiC Loop", "Enhancer Peak", "Enhancer DMR"]

# %%
N = 3
with PdfPages(f"../images/fig6/ff_geneXmodality_correct.pdf") as pdf:
    
    ### The non absolute --> Sum method
    for i, _ct in enumerate(cell_types): 
        # ax = axes.flatten()[i]
    
        shap_list = []
        for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
            # df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
            df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.shap_{_deg}.csv", index_col=0)
            df_shap = df_shap[(df_shap['DEG'] == df_shap['pred']) & (df_shap['DEG'] == _int_deg)]
            
            stat = df_shap[['DEG', 'pred']]
            df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T
            gene_list = df_shap.columns
            
            df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
            df_shap['modality'] = df_shap['modality'].map(FEATURE_MAP)

            
            df_shap = df_shap.groupby("modality").sum().abs()
            # df_shap_abs = df_shap.copy()
            # df_shap_abs[gene_list] = df_shap[gene_list].abs()
            
            # df_slice_list = []
            # for i, _gene in enumerate(gene_list): 
            #     indices = df_shap_abs[[_gene, 'modality']].groupby("modality")[_gene].nlargest(N).index.get_level_values(1)
            #     # df_slice = df_shap_abs.loc[indices, [_gene, 'modality']].groupby("modality").mean()
            #     df_slice = df_shap.loc[indices, [_gene, 'modality']].groupby("modality").sum().abs()
            #     df_slice_list.append(df_slice)
            # df_shap = pd.concat(df_slice_list, axis=1)
            # break
            
            df_list = []
            for m in FEAT_ORDER: 
                df_temp = df_shap[df_shap.index == m]
                # df_temp = df_temp.drop(columns = ['modality'])
                M = df_temp.shape[0]
                if M == 0: 
                    df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                    df_temp[m] = 0
                    df_list.append(df_temp)
                else: 
                    df_list.append(df_temp.T)
                    # df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}))
            # break
        
            df_shap = pd.concat(df_list, axis=1)   
            df_tt = df_shap.copy()
            df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=1)
            df_shap['DEG'] = stat['DEG']
            shap_list.append(df_shap)
        df_shap = pd.concat(shap_list)
        df_shap['DEG'] = df_shap['DEG'] - 1
        # df_shap = df_shap.sort_values(by=['DEG', 'ATAC', 'mCH_Genebody', 'mCG_Genebody'])
        
        pdist = spc.distance.pdist(df_shap)
        linkage = spc.linkage(pdist, method='complete')
        idx = spc.fcluster(linkage, 0.7*pdist.max(), 'distance')
        gene_order = [df_shap.index.tolist()[i] for i in list(np.argsort(idx))]
        df_shap = df_shap.loc[gene_order]
        df_shap = df_shap.sort_values(by=['DEG'])
    
        # Plotting
        n_samples=df_shap.shape[0]
        # toplot = df_shap[['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak']]    
        toplot = df_shap[FEAT_ORDER]
    
        left_ha = pch.HeatmapAnnotation(label = pch.anno_label(df_shap.DEG, merge=True, extend=False, adjust_color=True, luminance=0.75, relpos=(1, 0.5), colors='black'), 
                                        DEG_type = pch.anno_simple(df_shap.DEG, legend=True, colors=palette), 
                                        verbose=1, axis=0, plot_legend=False)
        
        fig = plt.figure(figsize=(5, 6))
        cm = ClusterMapPlotter(
            data = toplot, 
            left_annotation=left_ha,
            show_colnames=True, 
            vmin=0, vmax=0.3, 
            col_cluster=False, row_cluster=False, 
            cmap = 'coolwarm', rasterized=True, 
        )
        plt.suptitle(f"{_ct}: N={n_samples}")
        plt.ylabel("SHAP Value")
        pdf.savefig(dpi=300, bbox_inches='tight')
        plt.show()
        plt.close()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# ...

# %% [markdown]
# #### ModalityXDEG Importance

# %%
# fig, axes = plt.subplots(2, 5, figsize=(10, 5), dpi=300, constrained_layout=True)

CT_RES = {}
for i, _ct in enumerate(cell_types): 
    # ax = axes.flatten()[i]
    
    RES = {}
    for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
        # df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
        df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.shap_{_deg}.csv", index_col=0)
        df_shap = df_shap[(df_shap['DEG'] == df_shap['pred']) & (df_shap['DEG'] == _int_deg)]
        
        stat = df_shap[['DEG', 'pred']]
        df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T
        gene_list = df_shap.columns
        
        df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
        df_shap['modality'] = df_shap['modality'].map(FEATURE_MAP)
        
        # break
        df_shap = df_shap.groupby("modality").sum().abs()

        # df_shap_abs = df_shap.copy()
        # df_shap_abs[gene_list] = df_shap[gene_list].abs()
        
        # df_slice_list = []
        # for i, _gene in enumerate(gene_list): 
        #     indices = df_shap_abs[[_gene, 'modality']].groupby("modality")[_gene].nlargest(N).index.get_level_values(1)
        #     # df_slice = df_shap_abs.loc[indices, [_gene, 'modality']].groupby("modality").mean()
        #     df_slice = df_shap.loc[indices, [_gene, 'modality']].groupby("modality").sum().abs()
        #     df_slice_list.append(df_slice)
        # df_shap = pd.concat(df_slice_list, axis=1)
        
        df_list = []
        for m in FEAT_ORDER: 
            df_temp = df_shap[df_shap.index == m]
            # df_temp = df_temp.drop(columns = ['modality'])
            M = df_temp.shape[0]
            if M == 0: 
                df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                df_temp[m] = 0
                df_list.append(df_temp)
            else: 
                df_list.append(df_temp.T)
                # df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}))
        
        df_shap = pd.concat(df_list, axis=1).T 
        # df_shap = df_shap.groupby('modality').mean() # .mean(axis=1)
        df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=0)
        RES[_deg] = df_shap.mean(axis=1)
    
    CT_RES[_ct] = RES

#     sns.heatmap(pd.DataFrame.from_dict(RES).T, square=True, cmap='coolwarm', annot=True, cbar = False, ax=ax, 
#                 vmin=0, vmax=0.3)
#     # setting the annotation only when bigger than some value
#     for t in ax.texts:
#         if float(t.get_text())>=0.15:
#             t.set_text(t.get_text()) #if the value is greater than 0.4 then I set the text 
#         else:
#             t.set_text("") # if not it sets an empty text
#     ax.set_title(f"{_ct}")

# for i in range(len(cell_types), 3): 
#     axes.flatten()[i].remove()
# # plt.savefig("../images/fig6/degXmodality.pdf", bbox_inches= 'tight')
# plt.show()
# plt.close()

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 6), constrained_layout=True)

df_res_list  = []
for i, (_ct, RES) in enumerate(CT_RES.items()):
    df_res = pd.DataFrame.from_dict(RES).T
    df_res_list.append(df_res.reset_index(names='deg').melt(id_vars='deg', value_name=_ct, var_name='modality'))
    
    ax = axes.flatten()[i]
    
    g = ax.imshow(df_res, cmap='coolwarm', vmin=0, vmax=0.3)
    ax.set_xticks(range(df_res.shape[1]), labels=df_res.columns, 
                  rotation=45, ha='right', rotation_mode='anchor')
    ax.set_yticks(range(df_res.shape[0]), labels = df_res.index)
    # ax.tick_params(axis='x', )
    sns.despine(left=True, bottom=True)
    
    for a in range(df_res.shape[0]):
        for b in range(df_res.shape[1]):
            if float(df_res.iloc[a, b])>=0.15:
                ax.text(b, a, "%.2f"%(df_res.iloc[a, b]), size=10, va='center', ha='center')
    ax.set_title(f"{_ct}")

fig.colorbar(g, ax=axes, ticks=[0, 0.15, 0.3], label="", location='right', aspect=10, shrink=0.25, fraction=1)
# plt.savefig("../images/fig6/degXmodality.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %%
df_comb_res = pd.concat(df_res_list, axis=1)
df_comb_res = df_comb_res.loc[:, ~df_comb_res.columns.duplicated()].copy()
df_comb_res.head()

fig, axes = plt.subplots(1, 3, figsize=(16, 8), constrained_layout=True)

for i, _deg in enumerate(['down', 'non', 'up']):
    toplot = df_comb_res.loc[df_comb_res['deg'] == _deg].set_index('modality').drop(columns = 'deg').T
    # display(toplot.head())
    
    ax = axes.flatten()[i]
    
    g = ax.imshow(toplot, cmap='coolwarm', vmin=0, vmax=0.3)
    ax.set_xticks(range(toplot.shape[1]), labels=toplot.columns, 
                  rotation=90, ha='right', rotation_mode='anchor')
    ax.set_yticks(range(toplot.shape[0]), labels = toplot.index)
    # ax.tick_params(axis='x', )
    sns.despine(left=True, bottom=True)
    
    for a in range(toplot.shape[0]):
        for b in range(toplot.shape[1]):
            if float(toplot.iloc[a, b])>=0.15:
                ax.text(b, a, "%.2f"%(toplot.iloc[a, b]), size=10, va='center', ha='center')
    ax.set_title(f"{_deg}")
    
fig.colorbar(g, ax=axes, ticks=[0, 0.15, 0.3], label="", location='right', aspect=10, shrink=0.25, fraction=1)
plt.savefig("../images/fig6/ff_ctXmodality.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %% [markdown]
# #### Correlations

# %%
cell_types = ['Oligo_NN', 'OPC_NN', 'Astro-TE_NN', 'L23_IT_CTX_Glut', 'L6_IT_CTX_Glut', 'L6_CT_CTX_Glut', 'L5_ET_CTX_Glut', 'CA1-ProS_Glut', 'CA3_Glut', 'DG_Glut']

# %%
CT_RES = {}
for i, _ct in enumerate(cell_types): 
    
    RES = {}
    for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
        # df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
        df_shap = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.shap_{_deg}.csv", index_col=0)
        df_shap = df_shap[(df_shap['DEG'] == df_shap['pred']) & (df_shap['DEG'] == _int_deg)]
        
        stat = df_shap[['DEG', 'pred']]
        df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T
        gene_list = df_shap.columns
        
        df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
        df_shap['modality'] = df_shap['modality'].map(FEATURE_MAP)
        # break
        df_shap = df_shap.groupby("modality").sum().abs()
        # df_shap_abs = df_shap.copy()
        # df_shap_abs[gene_list] = df_shap[gene_list].abs()
        
        # df_slice_list = []
        # for i, _gene in enumerate(gene_list): 
        #     indices = df_shap_abs[[_gene, 'modality']].groupby("modality")[_gene].nlargest(N).index.get_level_values(1)
        #     # df_slice = df_shap_abs.loc[indices, [_gene, 'modality']].groupby("modality").mean()
        #     df_slice = df_shap.loc[indices, [_gene, 'modality']].groupby("modality").sum().abs()
        #     df_slice_list.append(df_slice)
        # df_shap = pd.concat(df_slice_list, axis=1)
        
        
        df_list = []
        for m in FEAT_ORDER: 
            df_temp = df_shap[df_shap.index == m]
            # df_temp = df_temp.drop(columns = ['modality'])
            M = df_temp.shape[0]
            if M == 0: 
                df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                df_temp[m] = 0
                df_list.append(df_temp)
            else: 
                df_list.append(df_temp.T)
                # df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}))
        
        df_shap = pd.concat(df_list, axis=1).T 
        # df_shap = df_shap.groupby('modality').mean() # .mean(axis=1)
        df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=0)
        RES[_deg] = df_shap.mean(axis=1)
    
    CT_RES[_ct] = RES

# %%
df_list = []
for _ct, shap_dict in CT_RES.items(): 
    df_mod = pd.DataFrame.from_dict(shap_dict).reset_index(names="index").melt(id_vars='index', value_name=_ct)
    df_mod['deg_modality'] = df_mod['variable'] + '_' + df_mod['index']
    df_mod = df_mod.drop(columns = ['variable', 'index']).set_index('deg_modality')
    df_list.append(df_mod)
df_mod = pd.concat(df_list, axis=1)

pdist = spc.distance.pdist(df_mod.T)
linkage = spc.linkage(pdist, method='complete')
idx = spc.fcluster(linkage, 0.6*pdist.max(), 'distance')
columns = [df_mod.columns.tolist()[i] for i in list(np.argsort(idx))]

# %%
corr_vals = df_mod[columns].corr()
corr_vals = np.power(corr_vals, 2)

# sns.heatmap(corr_vals, vmin = 0, vmax = 1)

fig, ax = plt.subplots(1,1,figsize=(6, 5), dpi=300, constrained_layout=True)

g = ax.imshow(corr_vals, vmin=0, vmax=1, cmap='Reds')

ax.set_xticks(range(corr_vals.shape[1]), labels=corr_vals.columns, 
                  rotation=45, ha='right', rotation_mode='anchor')
ax.set_yticks(range(corr_vals.shape[0]), labels = corr_vals.index)


sns.despine(bottom=True, left=True)


fig.colorbar(g, ax=ax, ticks=[0, 0.5, 1], label="", location='right', aspect=10, shrink=0.25, fraction=1)

# plt.savefig("../images/fig6/celltype_corr.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %% [markdown]
# # Linear Models

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 8), constrained_layout=True)
 
for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    Y_output = pd.read_csv(f"../result_data/linear_baseline/model_metrics/{_ct}.preds.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf = confusion_matrix(Y_output['label'], Y_output['pred'], normalize='true')
    sns.heatmap(ccf, 
            ax =ax,
            cmap = adj_coolwarm,
            vmin = 0.2, vmax = 0.8,
            annot=True)
    # ax.set_title(f'{_ct}:{n_genes}') 
    
    Y_deg = Y_output[(Y_output['label'] == 0) | (Y_output['label'] == 2)]
    acc = sum(Y_deg.label == Y_deg.pred) / Y_deg.shape[0]
    
    ax.set_title(f"{_ct}; n = {n_sample}; acc = {acc*100 :.1f}%", fontsize=10)
    
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")

# fig.colorbar(g, ax=axes, ticks=[0.2, 0.4, 0.6, 0.8], label="", location='right', aspect=10, shrink=0.25, fraction=1)
fig.savefig("../images/fig6/ff_linear_model_accuracies_2.pdf", bbox_inches= 'tight')
# plt.show()    
# plt.close()

# %%
acc_list = []
fig, axes = plt.subplots(2, 5, figsize=(20, 8), constrained_layout=True)

for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    Y_output = pd.read_csv(f"../result_data/linear_baseline/model_metrics/{_ct}.preds.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf = confusion_matrix(Y_output['label'], Y_output['pred'], normalize='true')
    g = ax.imshow(ccf, cmap=adj_coolwarm, vmin=0.2, vmax=0.8)
    ax.set(xticks=range(ccf.shape[1]), yticks=range(ccf.shape[0]), 
           xticklabels = ['-1', '0', '1'], yticklabels = ['-1', '0', '1'], 
           )
    sns.despine(left=True, bottom=True)

    for a in range(3):
        for b in range(3):
            ax.text(a, b, "%.2f"%(ccf[a, b]), size=12, va='center', ha='center', 
                   color = 'black' if (ccf[a,b] > 0.3) and (ccf[a,b] < 0.61) else 'white')
            
    Y_deg = Y_output[(Y_output['label'] == 0) | (Y_output['label'] == 2)]
    acc = sum(Y_deg.label == Y_deg.pred) / Y_deg.shape[0]
    acc_list.append(acc)
    ax.set_title(f"{_ct}; n = {n_sample}; acc = {acc*100 :.1f}%", fontsize=10)
    ax.set_xlabel("Actual")
    ax.set_ylabel("Predicted")

for i in range(len(cell_types), 3): 
    axes.flatten()[i].remove()

fig.colorbar(g, ax=axes, ticks=[0.2, 0.4, 0.6, 0.8], label="", location='right', aspect=10, shrink=0.25, fraction=1)
plt.savefig("../images/fig6/ff_linear_model_accuracies.pdf", bbox_inches= 'tight')
plt.show()    
plt.close()

# %%
np.mean(acc_list), np.std(acc_list)
# Out:
# (0.6147796338244583, 0.057016140121523055)

# %%
diag_acc = {}
n_samps = {}
for i, _ct in enumerate(cell_types): 

    Y_output = pd.read_csv(f"../result_data/linear_baseline/model_metrics/{_ct}.preds.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf_test = confusion_matrix(Y_output['label'], Y_output['pred'], normalize='true')
    diag_acc[_ct] = [ccf_test[0, 0], ccf_test[1, 1], ccf_test[2, 2]]
    n_samps[_ct] = [(Y_output['label'] == 0).sum(), (Y_output['label'] == 1).sum(), (Y_output['label'] == 2).sum()]
    # break
df_diag_acc = pd.DataFrame.from_dict(diag_acc)
df_N = pd.DataFrame.from_dict(n_samps)

# %%
linear_diag_acc = df_diag_acc.copy() # for downstream analysis

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300, constrained_layout=True)

g = ax.imshow(df_diag_acc, cmap=adj_coolwarm, vmin=0, vmax=1)
ax.set(xticks=range(df_diag_acc.shape[1]), yticks=range(df_diag_acc.shape[0]), 
       xticklabels=df_diag_acc.columns, yticklabels = ['-1', '0', '1'], )
ax.tick_params(axis='x', rotation=45)
sns.despine(left=True, bottom=True)

for a in range(df_diag_acc.shape[0]):
    for b in range(df_diag_acc.shape[1]):
        ax.text(b, a, "%.3f"%(df_diag_acc.iloc[a, b]), size=10, va='center', ha='center')
        
ax.set_title(f"TP summary (all celltypes)")

# sns.heatmap(df_diag_acc, square=True, cmap=adj_coolwarm, annot=True, vmin=0, vmax=1, center=0.33,
#             yticklabels=['-1', '0', '1'], ax=ax)

fig.colorbar(g, ax=ax, ticks=[0, 0.33, 0.66, 1], label="", location='right', aspect=10, shrink=0.25, fraction=1)

# plt.savefig("../images/linear_out/model_accuracies_box.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %% [markdown]
# # XGBoost

# %% [markdown]
# ## Accuracies

# %%
fig, axes = plt.subplots(2, 5, figsize=(16, 7), constrained_layout=True)

for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    # Y_output = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.Y_outs.csv", index_col=0)
    Y_output = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.Y_outs.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf = confusion_matrix(Y_output['DEG'], Y_output['pred'], normalize='true')
    g = ax.imshow(ccf, cmap=adj_coolwarm, vmin=0, vmax=1)
    ax.set(xticks=range(ccf.shape[1]), yticks=range(ccf.shape[0]), 
           xticklabels = ['-1', '0', '1'], yticklabels = ['-1', '0', '1'], 
           )
    sns.despine(left=True, bottom=True)

    for a in range(3):
        for b in range(3):
            ax.text(a, b, "%.3f"%(ccf[a, b]), size=10, va='center', ha='center')
            
    ax.set_title(f"{_ct}; n = {n_sample}")

for i in range(len(cell_types), 10): 
    axes.flatten()[i].remove()

fig.colorbar(g, ax=axes, ticks=[0, 0.33, 0.66, 1], label="", location='right', aspect=10, shrink=0.25, fraction=1)
# plt.savefig("../images/xgb_out/model_accuracies.pdf", bbox_inches= 'tight')
plt.show()    
plt.close()

# %%
# fig, axes = plt.subplots(2, 5, figsize=(16, 8), dpi=300, constrained_layout=True)

# for i, _ct in enumerate(cell_types): 
#     ax = axes.flatten()[i]
    
#     Y_output = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.Y_outs.csv", index_col=0)
#     n_sample = Y_output.shape[0]
    
#     ccf_test = confusion_matrix(Y_output['DEG'], Y_output['pred'], normalize='true')
#     sns.heatmap(ccf_test, vmin=0, vmax=1, center=0.33, xticklabels = ['-1', '0', '1'], yticklabels = ['-1', '0', '1'], 
#                 square=True, cmap='coolwarm', annot=True, cbar = False, ax=ax)
#     ax.set_title(f"{_ct}; n = {n_sample}")

# for i in range(len(cell_types), 10): 
#     axes.flatten()[i].remove()

# # plt.savefig("../images/xgb_out/model_accuracies_07.pdf", bbox_inches= 'tight')
# plt.show()
# plt.close()

# %%
diag_acc = {}
n_samps = {}
for i, _ct in enumerate(cell_types): 

    # Y_output = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.Y_outs.csv", index_col=0)
    Y_output = pd.read_csv(f"../result_data/xgb_mods_2/shap_feats/{_ct}.bal_det.Y_outs.csv", index_col=0)
    n_sample = Y_output.shape[0]
    
    ccf_test = confusion_matrix(Y_output['DEG'], Y_output['pred'], normalize='true')
    diag_acc[_ct] = [ccf_test[0, 0], ccf_test[1, 1], ccf_test[2, 2]]
    n_samps[_ct] = [(Y_output['DEG'] == 0).sum(), (Y_output['DEG'] == 1).sum(), (Y_output['DEG'] == 2).sum()]
    # break
df_diag_acc = pd.DataFrame.from_dict(diag_acc)
df_N = pd.DataFrame.from_dict(n_samps)

# %%
xgb_diag_acc = df_diag_acc.copy() # for downstream analysis

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=300, constrained_layout=True)

g = ax.imshow(df_diag_acc, cmap=adj_coolwarm, vmin=0, vmax=1)
ax.set(xticks=range(df_diag_acc.shape[1]), yticks=range(df_diag_acc.shape[0]), 
       xticklabels=df_diag_acc.columns, yticklabels = ['-1', '0', '1'], )
ax.tick_params(axis='x', rotation=45)
sns.despine(left=True, bottom=True)

for a in range(df_diag_acc.shape[0]):
    for b in range(df_diag_acc.shape[1]):
        ax.text(b, a, "%.3f"%(df_diag_acc.iloc[a, b]), size=10, va='center', ha='center')
        
ax.set_title(f"TP summary (all celltypes)")

# sns.heatmap(df_diag_acc, square=True, cmap=adj_coolwarm, annot=True, vmin=0, vmax=1, center=0.33,
#             yticklabels=['-1', '0', '1'], ax=ax)

fig.colorbar(g, ax=ax, ticks=[0, 0.33, 0.66, 1], label="", location='right', aspect=10, shrink=0.25, fraction=1)

# plt.savefig("../images/xgb_out/model_accuracies_box.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %%
# fig, ax = plt.subplots(figsize=(8, 4), dpi=300, constrained_layout=True)
# sns.heatmap(df_diag_acc, square=True, cmap='coolwarm', annot=True, vmin=0, vmax=1, center=0.33,
#             yticklabels=['-1', '0', '1'], ax=ax)
# # plt.savefig("../images/xgb_out/model_accuracies_box_01.pdf", bbox_inches= 'tight')
# plt.show()
# plt.close()

# %%
toplot = df_diag_acc.melt(ignore_index=False).reset_index() # .set_index("variable")
toplot.columns = ['DEG', 'celltype', 'acc']
df_tt = df_N.melt(ignore_index=False).reset_index() # .set_index("variable")
df_tt.columns = ['DEG', 'celltype', 'N']
toplot = toplot.merge(df_tt, on=['DEG', 'celltype'])
toplot['DEG'] = toplot['DEG'].map({0 : "Down", 1 : "Non", 2 : "Up"})

df_row = toplot.groupby('celltype').sum().reset_index()
df_row['NN'] = df_row['celltype'].apply(lambda x: 'NN' if 'NN' in x else 'Glut')
df_row = df_row.set_index('celltype')
df_col = pd.DataFrame({'DEG' : ['Down', 'Non', 'Up']}, index=['Down', 'Non', 'Up'])

# %%
palette = {'Down': '#4287f5', 'Non': '#ebedf0', 'Up': '#f50511'}

row_ha = HeatmapAnnotation(CellClass=anno_simple(df_row.NN, cmap='Set1', add_text=False, legend=False), 
                           label=anno_label(df_row.NN, merge=True, rotation=0), 
                           axis=0, verbose=0, label_kws={'rotation':45, 'horizontalalignment':'left'}
                          )

col_ha = HeatmapAnnotation(Label=anno_simple(df_col.DEG, colors=palette, legend=False, add_text=True), 
                           verbose=0, label_side='left',)

plt.figure(figsize=(8,4), dpi=300)
cm = DotClustermapPlotter(toplot, x='DEG', y='celltype', value='acc', s='N', cmap="adjusted_coolwarm", 
                          c='acc', vmax=1, vmin=0, linewidth=0, row_split=df_row.NN,
                         show_colnames=False, show_rownames=True, row_cluster=False, alpha=0.3, 
                         right_annotation=row_ha, top_annotation=col_ha)
plt.savefig("../images/xgb_out/model_accuracies_dot.pdf", bbox_inches= 'tight')
plt.show()
plt.close()
# Out:
# /gale/netapp/home2/aklein/miniconda3/envs/agp/lib/python3.10/site-packages/PyComplexHeatmap/dotHeatmap.py:356: FutureWarning: The provided callable <function mean at 0x7f50080d60e0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data2d = data.pivot_table(
# /gale/netapp/home2/aklein/miniconda3/envs/agp/lib/python3.10/site-packages/PyComplexHeatmap/dotHeatmap.py:375: FutureWarning: The provided callable <function mean at 0x7f50080d60e0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   self.kwargs["s"] = data.pivot_table(
# /gale/netapp/home2/aklein/miniconda3/envs/agp/lib/python3.10/site-packages/PyComplexHeatmap/dotHeatmap.py:391: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %% [markdown]
# ## Gene x modality

# %%
palette = {-1: '#4287f5', 0: '#ebedf0', 1: '#f50511'}
FEATURE_LIST = ['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak'] # , 'meta']
def generate():
    proba = np.random.random()
    max = 0
    for i in range(1,M+1):
         max += (1/2)**i
         if(proba<= max):
              return i-1
    return generate()

# %%
with PdfPages(f"../images/xgb_out/geneXmodality_correct.pdf") as pdf:
    
    for i, _ct in enumerate(cell_types): 
        
        shap_list = []
        for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
            df_shap = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
            df_shap = df_shap[(df_shap['DEG'] == df_shap['pred']) & (df_shap['DEG'] == _int_deg)]
            
            stat = df_shap[['DEG', 'pred']]
            df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T.abs()
            df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
            # break
            
            df_list = []
            for m in FEATURE_LIST: 
                df_temp = df_shap[df_shap['modality'] == m]
                df_temp = df_temp.drop(columns = ['modality'])
                M = df_temp.shape[0]
                if M == 0: 
                    df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                    df_temp[m] = 0
                    df_list.append(df_temp)
                else: 
                    res = [0 for i in range(M)]
                    for i in range(1000):
                        res[generate()]+=1
                
                    df_temp = df_temp.apply(lambda x: np.average(sorted(x, reverse=True), weights=res), axis=0)
                    df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}))
            # break
        
            df_shap = pd.concat(df_list, axis=1)   
            df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=1)
            df_shap['DEG'] = stat['DEG']
            shap_list.append(df_shap)
        df_shap = pd.concat(shap_list)
        df_shap['DEG'] = df_shap['DEG'] - 1
    
        # Plotting
        n_samples=df_shap.shape[0]
        toplot = df_shap[['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak']]    
    
        left_ha = pch.HeatmapAnnotation(label = pch.anno_label(df_shap.DEG, merge=True, extend=False, adjust_color=True, luminance=0.75, relpos=(1, 0.5), colors='black'), 
                                        DEG_type = pch.anno_simple(df_shap.DEG, legend=True, colors=palette), 
                                        verbose=1, axis=0, plot_legend=False)
        
        fig = plt.figure(figsize=(5, 6))
        cm = ClusterMapPlotter(
            data = toplot, 
            left_annotation=left_ha,
            show_colnames=True, 
            vmin=0, vmax=0.3, 
            col_cluster=False, row_cluster=False, 
            cmap = 'coolwarm', rasterized=True, 
        )
        plt.suptitle(f"{_ct}: N={n_samples}")
        plt.ylabel("Genes")
        pdf.savefig(dpi=300, bbox_inches='tight')
        plt.close()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# ...

# %%
with PdfPages(f"../images/xgb_out/geneXmodality_incorrect.pdf") as pdf:

    for i, _ct in enumerate(cell_types): 
    
        shap_list = []
        for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
            df_shap = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
            df_shap = df_shap[(df_shap['DEG'] != df_shap['pred']) & (df_shap['pred'] == _int_deg)]
            
            stat = df_shap[['DEG', 'pred']]
            df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T.abs()
            df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
            
            df_list = []
            for m in FEATURE_LIST: 
                df_temp = df_shap[df_shap['modality'] == m]
                df_temp = df_temp.drop(columns = ['modality'])
                M = df_temp.shape[0]
                if M == 0: 
                    df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                    df_temp[m] = 0
                    df_list.append(df_temp)
                else: 
                    res = [0 for i in range(M)]
                    for i in range(1000):
                        res[generate()]+=1
                
                    df_temp = df_temp.apply(lambda x: np.average(sorted(x, reverse=True), weights=res), axis=0)
                    df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}))
            # break
        
            df_shap = pd.concat(df_list, axis=1)   
            df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=1)
            df_shap['pred'] = stat['pred']
            df_shap['DEG'] = stat['DEG']
            shap_list.append(df_shap)
        df_shap = pd.concat(shap_list)
        df_shap['pred'] = df_shap['pred'] - 1
        df_shap['DEG'] = df_shap['DEG'] - 1
        df_shap = df_shap.sort_values(by=['pred', 'DEG'])
        df_shap = df_shap.loc[~(df_shap.index == 'modality')]
    
        # Plotting
        n_samples=df_shap.shape[0]
        toplot = df_shap[['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak']]    
    
        left_ha = pch.HeatmapAnnotation(label = pch.anno_label(df_shap.pred, merge=True, extend=False, adjust_color=True, luminance=0.75, relpos=(1, 0.5), colors='black'), 
                                        Pred = pch.anno_simple(df_shap.pred, legend=True, colors=palette), 
                                        Label = pch.anno_simple(df_shap.DEG, legend=True, colors=palette), 
                                        verbose=1, axis=0, plot_legend=False)
        
        fig = plt.figure(figsize=(5, 6))
        cm = ClusterMapPlotter(
            data = toplot, 
            left_annotation=left_ha,
            show_colnames=True, 
            vmin=0, vmax=0.3, 
            row_split=df_shap.pred,
            col_cluster=False, row_cluster=False, 
            cmap = 'coolwarm', rasterized=True, 
        )
        plt.suptitle(f"{_ct}: N={n_samples}")
        plt.ylabel("Genes")
        pdf.savefig(dpi=300, bbox_inches='tight')
        plt.close()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm
# ...

# %% [markdown]
# ## DEG x Modality

# %%
FEATURE_LIST = ['DMR', 'mcg_genebody', 'mch_genebody', 'atac', 'DAR', 'loops', 'enhancer_DMR', 'enhancer_peak'] #, 'meta']
FEATURE_MAP = {'DMR' : "mCG_DMR",
               'mcg_genebody' : "mCG_Genebody",
               'mch_genebody' : "mCH_Genebody",
               'atac' : "ATAC",
               'DAR' : "ATAC",
               'loops' : "hic_loops",
               'enhancer_DMR' : "enhancer_DMR",
               'enhancer_peak' : "enhancer_peak"
}
FEAT_ORDER = ["mCG_DMR", "mCG_Genebody", "mCH_Genebody", "ATAC", "hic_loops", "enhancer_DMR", "enhancer_peak"]

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 7), dpi=300, constrained_layout=True)

CT_RES = {}
for i, _ct in enumerate(cell_types): 
    ax = axes.flatten()[i]
    
    RES = {}
    for _deg, _int_deg in zip(['down', 'non', 'up'], [0, 1, 2]): 
        df_shap = pd.read_csv(f"../result_data/xgb_mods/shap_feats/{_ct}.cv{extension}.shap_{_deg}.csv", index_col=0)
        df_shap = df_shap[(df_shap['DEG'] == df_shap['pred']) & (df_shap['DEG'] == _int_deg)]
        
        stat = df_shap[['DEG', 'pred']]
        df_shap = df_shap[df_shap.columns.difference(['DEG', 'pred'])].T.abs()
        df_shap['modality'] = [idx.split(".")[-1] for idx in df_shap.index]
        df_shap['modality'] = df_shap['modality'].map(FEATURE_MAP)
        # break
        
        df_list = []
        for m in FEAT_ORDER: 
            df_temp = df_shap[df_shap['modality'] == m]
            df_temp = df_temp.drop(columns = ['modality'])
            M = df_temp.shape[0]
            if M == 0: 
                df_temp = pd.DataFrame(df_shap.columns).set_index("gene_name")
                df_temp[m] = 0
                df_list.append(df_temp.T)
            else: 
                res = [0 for i in range(M)]
                for i in range(1000):
                    res[generate()]+=1
            
                df_temp = df_temp.apply(lambda x: np.average(sorted(x, reverse=True), weights=res), axis=0)
                df_list.append(pd.DataFrame(df_temp).rename(columns={0:m}).T)
        # break
    
        df_shap = pd.concat(df_list)    
        # df_shap = df_shap.groupby('modality').mean() # .mean(axis=1)
        df_shap = df_shap.apply(lambda x: (x - min(x)) / sum(x - min(x)), axis=0)
        RES[_deg] = df_shap.mean(axis=1)
    
    CT_RES[_ct] = RES

    sns.heatmap(pd.DataFrame.from_dict(RES).T, square=True, cmap='coolwarm', annot=True, cbar = False, ax=ax, 
                vmin=0, vmax=0.3)
    # setting the annotation only when bigger than some value
    for t in ax.texts:
        if float(t.get_text())>=0.15:
            t.set_text(t.get_text()) #if the value is greater than 0.4 then I set the text 
        else:
            t.set_text("") # if not it sets an empty text
    ax.set_title(f"{_ct}")

for i in range(len(cell_types), 10): 
    axes.flatten()[i].remove()
plt.savefig("../images/xgb_out/degXmodality.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %%
df_list = []
for _ct, shap_dict in CT_RES.items(): 
    df_mod = pd.DataFrame.from_dict(shap_dict).reset_index().melt(id_vars='index', value_name=_ct)
    df_mod['deg_modality'] = df_mod['variable'] + '_' + df_mod['index']
    df_mod = df_mod.drop(columns = ['variable', 'index']).set_index('deg_modality')
    df_list.append(df_mod)
df_mod = pd.concat(df_list, axis=1)

# %%
pdist = spc.distance.pdist(df_mod.T)
linkage = spc.linkage(pdist, method='complete')
idx = spc.fcluster(linkage, 0.5*pdist.max(), 'distance')
columns = [df_mod.columns.tolist()[i] for i in list(np.argsort(idx))]

# %%
corr_vals = df_mod[columns].corr()
corr_vals = np.power(corr_vals, 2)
plt.figure(figsize=(6, 5), dpi=300, constrained_layout=True)
sns.heatmap(corr_vals, vmin = 0, vmax = 1)
plt.savefig("../images/xgb_out/celltype_corr.pdf", bbox_inches= 'tight')
plt.show()
plt.close()

# %% [markdown]
# # Comparing Linear to XGBoost

# %%
from scipy import stats

# %%
acc_differences = (xgb_diag_acc - linear_diag_acc).values.flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 acc_differences = (xgb_diag_acc - linear_diag_acc).values.flatten()
#
# NameError: name 'xgb_diag_acc' is not defined

# %%
stats.ttest_1samp(acc_differences, popmean=0, alternative='greater')
# Out:
# TtestResult(statistic=4.816692315737074, pvalue=2.1107441877682207e-05, df=29)

# %%
kde = stats.gaussian_kde(acc_differences)
fig, ax = plt.subplots(figsize=(6, 3), constrained_layout=True)
ax.hist(acc_differences, density=True, bins=20, alpha=0.7, color='#FFA500')

x = np.linspace(-0.1, 0.25, 1000)
ax.plot(x, kde(x), c='#8A3324')

ax.axvline(x=0, c='k', linestyle='--')

ax.set_title("Difference in TP rate b/w XGBoost and Logistic model")
ax.set_xlabel("Difference between TP rate")
ax.set_ylabel("Count")
plt.show()
